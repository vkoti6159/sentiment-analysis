# %% [markdown]
# Title : Simple Classification Dogs & Cats

# %%
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow import keras
from keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dropout,Flatten,Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
import matplotlib.image as mpimg

# %%
data_path = r'C:\Users\varik\Downloads\kagglecatsanddogs_5340 (1).zip'
if os.path.exists(data_path):
    print(f"✅ File found at: {data_path}")
else:
    print(f"❌ Error: File not found at {data_path}")
import zipfile

if zipfile.is_zipfile(data_path):
    print("✅ File is a valid ZIP archive.")
else:
    print("❌ Error: File is not a valid ZIP archive.")
# Out:
# ✅ File found at: C:\Users\varik\Downloads\kagglecatsanddogs_5340 (1).zip
# ✅ File is a valid ZIP archive.

# %%
from zipfile import ZipFile
with ZipFile(data_path, 'r') as zip:
    zip.extractall()
    print("the data set has been extracted.")
data_path =  r'C:\Users\varik\Downloads\kagglecatsanddogs_5340 (1).zip'
classes = os.listdir(path)
classes

# %%
fig =plt.gcf()
fig .set_size_inches(16,16)
cat_dir=os.path.join("PetImages","Cat")
dog_dir=os.path.join("PetImages","Dog")
cat_names=os.listdir(cat_dir)
dog_names=os.listdir(dog_dir)
pic_index=210
cat_images =[ os.path.join(cat_dir,fname ) for fname in cat_names[pic_index -8:pic_index]]
dog_images= [ os.path.join(dog_dir,fname ) for fname in dog_names[pic_index -8:pic_index]] 
for i, img_path in enumerate(cat_images + dog_images):
    try:
        img = mpimg.imread(img_path)  # Try loading the image
        sp = plt.subplot(4, 4, i + 1)
        sp.axis('off')
        plt.imshow(img)
    except Exception as e:
        print(f"Skipping {img_path} due to error: {e}")

plt.show()

print(f"Found {len(cat_names)} cat images and {len(dog_names)} dog images.")
# Out:
# Found 12501 cat images and 12501 dog images.

# %%
cat_images = [os.path.join(cat_dir, fname) for fname in cat_names[pic_index - 8:pic_index]]
dog_images = [os.path.join(dog_dir, fname) for fname in dog_names[pic_index - 8:pic_index]]

# Debugging: Print the file paths
print("Cat images:", cat_images)
print("Dog images:", dog_images)
# Out:
# Cat images: ['PetImages\\Cat\\10179.jpg', 'PetImages\\Cat\\1018.jpg', 'PetImages\\Cat\\10180.jpg', 'PetImages\\Cat\\10181.jpg', 'PetImages\\Cat\\10182.jpg', 'PetImages\\Cat\\10183.jpg', 'PetImages\\Cat\\10184.jpg', 'PetImages\\Cat\\10185.jpg']
# Dog images: ['PetImages\\Dog\\10179.jpg', 'PetImages\\Dog\\1018.jpg', 'PetImages\\Dog\\10180.jpg', 'PetImages\\Dog\\10181.jpg', 'PetImages\\Dog\\10182.jpg', 'PetImages\\Dog\\10183.jpg', 'PetImages\\Dog\\10184.jpg', 'PetImages\\Dog\\10185.jpg']

# %%
plt.show(block=True)  # Forces Matplotlib to display the images properly

# %%
# %matplotlib inline

# %%
for i, img_path in enumerate(cat_images + dog_images):
    try:
        img = mpimg.imread(img_path)  # Try loading the image
        sp = plt.subplot(4, 4, i + 1)
        sp.axis('off')
        plt.imshow(img)
    except Exception as e:
        print(f"Skipping {img_path} due to error: {e}")

plt.show()
